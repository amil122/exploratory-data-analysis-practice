# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
 df_test = pd.read_csv('dataset/black_friday/test.csv')

# %%
df_train =  pd.read_csv('dataset/black_friday/train.csv')

# %%
df = pd.concat([df_train, df_test], ignore_index=True)

# %%
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 783662  1006036  P00118942      F  26-35          15             B
# 783663  1006036  P00254642      F  26-35          15             B
# 783664  1006036  P00031842      F  26-35          15             B
# 783665  1006037  P00124742      F  46-50           1             C
# 783666  1006039  P00316642      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 783667 entries, 0 to 783666
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     783667 non-null  int64
#  1   Product_ID                  783667 non-null  object
#  2   Gender                      783667 non-null  object
#  3   Age                         783667 non-null  object
#  4   Occupation                  783667 non-null  int64
#  5   City_Category               783667 non-null  object
#  6   Stay_In_Current_City_Years  783667 non-null  object
#  7   Marital_Status              783667 non-null  int64
#  8   Product_Category_1          783667 non-null  int64
#  9   Product_Category_2          537685 non-null  float64
#  10  Product_Category_3          237858 non-null  float64
#  11  Purchase                    550068 non-null  float64
# dtypes: float64(3), int64(4), object(5)
# ...

# %%
df.drop('User_ID',axis = 1, inplace = True)

# %%
df
# Out:
#        Product_ID Gender    Age  Occupation City_Category  \
# 0       P00069042      F   0-17          10             A
# 1       P00248942      F   0-17          10             A
# 2       P00087842      F   0-17          10             A
# 3       P00085442      F   0-17          10             A
# 4       P00285442      M    55+          16             C
# ...           ...    ...    ...         ...           ...
# 783662  P00118942      F  26-35          15             B
# 783663  P00254642      F  26-35          15             B
# 783664  P00031842      F  26-35          15             B
# 783665  P00124742      F  46-50           1             C
# 783666  P00316642      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# 1                               2               0                   1
# ...

# %%
df.isna().sum()
# Out:
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            245982
# Product_Category_3            545809
# Purchase                      233599
# dtype: int64

# %% [markdown]
# # Handling categorical value gender into 0 and 1

# %%
df['Gender'] = df['Gender'].apply(lambda x: 0 if x == 'M' else 1 if x == 'F' else x)

# %%
df
# Out:
#        Product_ID  Gender    Age  Occupation City_Category  \
# 0       P00069042       1   0-17          10             A
# 1       P00248942       1   0-17          10             A
# 2       P00087842       1   0-17          10             A
# 3       P00085442       1   0-17          10             A
# 4       P00285442       0    55+          16             C
# ...           ...     ...    ...         ...           ...
# 783662  P00118942       1  26-35          15             B
# 783663  P00254642       1  26-35          15             B
# 783664  P00031842       1  26-35          15             B
# 783665  P00124742       1  46-50           1             C
# 783666  P00316642       1  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# 1                               2               0                   1
# ...

# %% [markdown]
# # Handling categorical value age

# %%
df['Age'].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
df['Age'] = df['Age'].map({'0-17':1,'18-25':2,'26-35':3,'36-45':4,'46-50':5,'51-55':6,'55+':7})

# %%
df
# Out:
#        Product_ID  Gender  Age  Occupation City_Category  \
# 0       P00069042       1    1          10             A
# 1       P00248942       1    1          10             A
# 2       P00087842       1    1          10             A
# 3       P00085442       1    1          10             A
# 4       P00285442       0    7          16             C
# ...           ...     ...  ...         ...           ...
# 783662  P00118942       1    3          15             B
# 783663  P00254642       1    3          15             B
# 783664  P00031842       1    3          15             B
# 783665  P00124742       1    5           1             C
# 783666  P00316642       1    5           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# 1                               2               0                   1
# ...

# %%
df['City_Category'].unique()
# Out:
# array(['A', 'C', 'B'], dtype=object)

# %%
df_city = pd.get_dummies(df['City_Category'], drop_first = True)

# %%
df_city
# Out:
#             B      C
# 0       False  False
# 1       False  False
# 2       False  False
# 3       False  False
# 4       False   True
# ...       ...    ...
# 783662   True  False
# 783663   True  False
# 783664   True  False
# 783665  False   True
# 783666   True  False
#
# [783667 rows x 2 columns]

# %%
df = pd.concat([df,df_city], axis = 1)
df
# Out:
#        Product_ID  Gender  Age  Occupation City_Category  \
# 0       P00069042       1    1          10             A
# 1       P00248942       1    1          10             A
# 2       P00087842       1    1          10             A
# 3       P00085442       1    1          10             A
# 4       P00285442       0    7          16             C
# ...           ...     ...  ...         ...           ...
# 783662  P00118942       1    3          15             B
# 783663  P00254642       1    3          15             B
# 783664  P00031842       1    3          15             B
# 783665  P00124742       1    5           1             C
# 783666  P00316642       1    5           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# 1                               2               0                   1
# ...

# %%
df.drop('City_Category', axis = 1, inplace = True)

# %%
df
# Out:
#        Product_ID  Gender  Age  Occupation Stay_In_Current_City_Years  \
# 0       P00069042       1    1          10                          2
# 1       P00248942       1    1          10                          2
# 2       P00087842       1    1          10                          2
# 3       P00085442       1    1          10                          2
# 4       P00285442       0    7          16                         4+
# ...           ...     ...  ...         ...                        ...
# 783662  P00118942       1    3          15                         4+
# 783663  P00254642       1    3          15                         4+
# 783664  P00031842       1    3          15                         4+
# 783665  P00124742       1    5           1                         4+
# 783666  P00316642       1    5           0                         4+
#
#         Marital_Status  Product_Category_1  Product_Category_2  \
# ...

# %%
df.isna().sum()
# Out:
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            245982
# Product_Category_3            545809
# Purchase                      233599
# B                                  0
# C                                  0
# dtype: int64

# %%
df['Product_Category_2'] = df['Product_Category_2'].fillna(df['Product_Category_2'].mode()[0])

# %%
df['Product_Category_2'].isna().sum()
# Out:
# 0

# %%
df['Product_Category_2'].mode()
# Out:
# 0    8.0
# Name: Product_Category_2, dtype: float64

# %%
df['Product_Category_2']
# Out:
# 0          8.0
# 1          6.0
# 2          8.0
# 3         14.0
# 4          8.0
#           ...
# 783662     8.0
# 783663     8.0
# 783664     5.0
# 783665    16.0
# 783666     5.0
# Name: Product_Category_2, Length: 783667, dtype: float64

# %%
df['Product_Category_3'] = df['Product_Category_3'].fillna(df['Product_Category_3'].mode()[0])

# %%
df['Product_Category_2'].isna().sum()
# Out:
# 0

# %%
sns.boxplot(data = df, x= 'Purchase')
# Out:
# <Axes: xlabel='Purchase'>

# %%
df['Stay_In_Current_City_Years']= df['Stay_In_Current_City_Years'].str.replace('+','')

# %%
# df.info()
df
# Out:
#        Product_ID  Gender  Age  Occupation Stay_In_Current_City_Years  \
# 0       P00069042       1    1          10                          2
# 1       P00248942       1    1          10                          2
# 2       P00087842       1    1          10                          2
# 3       P00085442       1    1          10                          2
# 4       P00285442       0    7          16                          4
# ...           ...     ...  ...         ...                        ...
# 783662  P00118942       1    3          15                          4
# 783663  P00254642       1    3          15                          4
# 783664  P00031842       1    3          15                          4
# 783665  P00124742       1    5           1                          4
# 783666  P00316642       1    5           0                          4
#
#         Marital_Status  Product_Category_1  Product_Category_2  \
# ...

# %%
 df['Stay_In_Current_City_Years'] = df['Stay_In_Current_City_Years'].astype(int)

# %%
df['B'] = df['B'].astype(int)
df['C'] = df['C'].astype(int)

# %%
df['Gender'] = pd.Categorical(df['Gender'])

sns.barplot( data =df,x= 'Age',y ='Purchase')
# Out:
# <Axes: xlabel='Age', ylabel='Purchase'>

# %%
print(df.dtypes)
# Out:
# Product_ID                      object
# Gender                        category
# Age                              int64
# Occupation                       int64
# Stay_In_Current_City_Years       int32
# Marital_Status                   int64
# Product_Category_1               int64
# Product_Category_2             float64
# Product_Category_3             float64
# Purchase                       float64
# B                                int32
# C                                int32
# dtype: object

# %%
df['Gender'] = df['Gender'].map({1: 'Male', 0: 'Female'}).astype('category')

# Plotting the bar plot using keyword arguments
sns.barplot(x='Product_Category_1', y='Purchase', hue='Gender', data=df)
plt.show()
